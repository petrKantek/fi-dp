# %% [markdown]
# ### Research questions 1-4

# %%
import os
import pandas as pd
import numpy as np
pd.set_option("display.max_rows", 140)

def count_lines_in_csv(file_path):
    try:
        df = pd.read_csv(file_path, header=None)
        return len(df)
    except pd.errors.EmptyDataError:
        return 0
    except Exception as e:
        print(f"Error reading {file_path}: {e}")
        return None

def process_csv_files(directory, unique=False):
    data = {'RQ': [], 'Tool': [], 'CWE': [], 'Scenario': [], 'Count lines': []}

    for root, dirs, files in os.walk(directory):
        for file_name in files:
            if file_name.endswith('.csv'):
                
                file_path = os.path.join(root, file_name)
                root_parts = str(file_path).split(os.sep)


                rq, tool, cwe, scenario = root_parts[1], root_parts[2], root_parts[3], root_parts[4]

                lines_count = count_lines_in_csv(file_path)

                if unique:
                    lines_count = min(lines_count, 1)

                data['RQ'].append(rq)
                data['Tool'].append(tool)
                data['CWE'].append(cwe)
                data['Scenario'].append(scenario)
                data['Count lines'].append(lines_count)

    df = pd.DataFrame(data)
    return df

# %%
root_directory = '../vulnerability_analysis'

codeql_results = process_csv_files(root_directory)
codeql_results
# Out:
#        RQ     Tool      CWE                 Scenario  Count lines
# 0    rq_1  chatgpt   cwe_20     scenario_cwe_context            2
# 1    rq_1  chatgpt   cwe_20  scenario_cwe_definition            2
# 2    rq_1  chatgpt   cwe_20       scenario_secureval            1
# 3    rq_1  chatgpt   cwe_22     scenario_cwe_context            0
# 4    rq_1  chatgpt   cwe_22  scenario_cwe_definition            0
# ..    ...      ...      ...                      ...          ...
# 671  rq_4  tabnine  cwe_918  scenario_cwe_definition            0
# 672  rq_4  tabnine  cwe_918       scenario_secureval            1
# 673  rq_4  tabnine   cwe_94     scenario_cwe_context            0
# 674  rq_4  tabnine   cwe_94  scenario_cwe_definition            0
# 675  rq_4  tabnine   cwe_94       scenario_secureval            1
#
# [676 rows x 5 columns]

# %%
(codeql_results["Count lines"] > 0).sum()/len(codeql_results)
# Out:
# 0.2529585798816568

# %%
codeql_results["Count lines"].sum()
# Out:
# 255

# %%
codeql_results.groupby(["RQ", "Tool", "Scenario"])["Count lines"].sum()
# Out:
# RQ    Tool      Scenario
# rq_1  chatgpt   scenario_cwe_context       13
#                 scenario_cwe_definition    16
#                 scenario_secureval         11
#       codegeex  scenario_cwe_context       11
#                 scenario_cwe_definition     7
#                 scenario_secureval         12
#       copilot   scenario_cwe_context        6
#                 scenario_cwe_definition     9
#                 scenario_secureval          6
#       tabnine   scenario_cwe_context        8
#                 scenario_cwe_definition    12
#                 scenario_secureval          6
# rq_2  chatgpt   scenario_cwe_context        2
#                 scenario_cwe_definition     3
#                 scenario_secureval          3
#       codegeex  scenario_cwe_context        3
#                 scenario_cwe_definition     0
#                 scenario_secureval          0
#       copilot   scenario_cwe_context        1
#                 scenario_cwe_definition     3
#                 scenario_secureval          3
#       tabnine   scenario_cwe_context        5
#                 scenario_cwe_definition     2
#                 scenario_secureval          3
# rq_3  chatgpt   scenario_cwe_context        3
#                 scenario_cwe_definition     1
#                 scenario_secureval          3
#       codegeex  scenario_cwe_context        0
#                 scenario_cwe_definition     1
#                 scenario_secureval          1
#       copilot   scenario_cwe_context        1
#                 scenario_cwe_definition     1
#                 scenario_secureval          3
#       tabnine   scenario_cwe_context        2
#                 scenario_cwe_definition     1
#                 scenario_secureval          3
# rq_4  chatgpt   scenario_cwe_context        7
#                 scenario_cwe_definition    12
#                 scenario_secureval          6
#       codegeex  scenario_cwe_context       10
#                 scenario_cwe_definition     6
#                 scenario_secureval          3
#       copilot   scenario_cwe_context        5
#                 scenario_cwe_definition     7
#                 scenario_secureval          4
#       tabnine   scenario_cwe_context        9
#                 scenario_cwe_definition     3
#                 scenario_secureval         18
# Name: Count lines, dtype: int64

# %%
codeql_results.groupby(["RQ"])["Count lines"].sum()
# Out:
# RQ
# rq_1    117
# rq_2     28
# rq_3     20
# rq_4     90
# Name: Count lines, dtype: int64

# %%
codeql_results.groupby(["RQ", "Tool"])["Count lines"].sum()
# Out:
# RQ    Tool
# rq_1  chatgpt     40
#       codegeex    30
#       copilot     21
#       tabnine     26
# rq_2  chatgpt      8
#       codegeex     3
#       copilot      7
#       tabnine     10
# rq_3  chatgpt      7
#       codegeex     2
#       copilot      5
#       tabnine      6
# rq_4  chatgpt     25
#       codegeex    19
#       copilot     16
#       tabnine     30
# Name: Count lines, dtype: int64

# %%
codeql_results.groupby(["RQ", "Scenario"])["Count lines"].sum()
# Out:
# RQ    Scenario
# rq_1  scenario_cwe_context       38
#       scenario_cwe_definition    44
#       scenario_secureval         35
# rq_2  scenario_cwe_context       11
#       scenario_cwe_definition     8
#       scenario_secureval          9
# rq_3  scenario_cwe_context        6
#       scenario_cwe_definition     4
#       scenario_secureval         10
# rq_4  scenario_cwe_context       31
#       scenario_cwe_definition    28
#       scenario_secureval         31
# Name: Count lines, dtype: int64

# %%
codeql_results.groupby(["Scenario"])["Count lines"].sum()
# Out:
# Scenario
# scenario_cwe_context       86
# scenario_cwe_definition    84
# scenario_secureval         85
# Name: Count lines, dtype: int64

# %% [markdown]
# ### Research question 7 - validity of programs

# %%
def get_valid_programs(directory):
    data = {'RQ': [], 'Tool': [], 'CWE': [], 'Scenario': [], 'Num valid': []}

    for root, dirs, files in os.walk(directory):
        for file_name in files:
            if file_name.endswith('.csv'):
                file_path = os.path.join(root, file_name)
                root_parts = str(file_path).split(os.sep)

                rq, tool, cwe, scenario = root_parts[1], root_parts[2], root_parts[3], root_parts[4]

                data['RQ'].append(rq)
                data['Tool'].append(tool)
                data['CWE'].append(cwe)
                data['Scenario'].append(scenario)
                data['Num valid'].append(1)

    df = pd.DataFrame(data)
    return df

# Specify the root directory
root_directory = '../vulnerability_analysis'

valid_programs = get_valid_programs(root_directory)

# Display the resulting DataFrame
valid_programs
# Out:
#        RQ     Tool      CWE                 Scenario  Num valid
# 0    rq_1  chatgpt   cwe_20     scenario_cwe_context          1
# 1    rq_1  chatgpt   cwe_20  scenario_cwe_definition          1
# 2    rq_1  chatgpt   cwe_20       scenario_secureval          1
# 3    rq_1  chatgpt   cwe_22     scenario_cwe_context          1
# 4    rq_1  chatgpt   cwe_22  scenario_cwe_definition          1
# ..    ...      ...      ...                      ...        ...
# 671  rq_4  tabnine  cwe_918  scenario_cwe_definition          1
# 672  rq_4  tabnine  cwe_918       scenario_secureval          1
# 673  rq_4  tabnine   cwe_94     scenario_cwe_context          1
# 674  rq_4  tabnine   cwe_94  scenario_cwe_definition          1
# 675  rq_4  tabnine   cwe_94       scenario_secureval          1
#
# [676 rows x 5 columns]

# %%
valid_programs_grp = valid_programs.groupby(['RQ', 'Tool', 'Scenario'])['Num valid'].sum().reset_index()
valid_programs_grp
# Out:
#       RQ      Tool                 Scenario  Num valid
# 0   rq_1   chatgpt     scenario_cwe_context         14
# 1   rq_1   chatgpt  scenario_cwe_definition         14
# 2   rq_1   chatgpt       scenario_secureval         14
# 3   rq_1  codegeex     scenario_cwe_context         15
# 4   rq_1  codegeex  scenario_cwe_definition         15
# 5   rq_1  codegeex       scenario_secureval         15
# 6   rq_1   copilot     scenario_cwe_context         15
# 7   rq_1   copilot  scenario_cwe_definition         15
# 8   rq_1   copilot       scenario_secureval         15
# 9   rq_1   tabnine     scenario_cwe_context         15
# 10  rq_1   tabnine  scenario_cwe_definition         15
# 11  rq_1   tabnine       scenario_secureval         15
# 12  rq_2   chatgpt     scenario_cwe_context         15
# 13  rq_2   chatgpt  scenario_cwe_definition         15
# 14  rq_2   chatgpt       scenario_secureval         15
# 15  rq_2  codegeex     scenario_cwe_context         11
# 16  rq_2  codegeex  scenario_cwe_definition          8
# 17  rq_2  codegeex       scenario_secureval         10
# 18  rq_2   copilot     scenario_cwe_context         15
# 19  rq_2   copilot  scenario_cwe_definition         15
# 20  rq_2   copilot       scenario_secureval         15
# 21  rq_2   tabnine     scenario_cwe_context         12
# 22  rq_2   tabnine  scenario_cwe_definition         12
# 23  rq_2   tabnine       scenario_secureval         13
# 24  rq_3   chatgpt     scenario_cwe_context         13
# 25  rq_3   chatgpt  scenario_cwe_definition         13
# 26  rq_3   chatgpt       scenario_secureval         17
# 27  rq_3  codegeex     scenario_cwe_context          7
# 28  rq_3  codegeex  scenario_cwe_definition          6
# 29  rq_3  codegeex       scenario_secureval          8
# 30  rq_3   copilot     scenario_cwe_context         11
# 31  rq_3   copilot  scenario_cwe_definition         11
# 32  rq_3   copilot       scenario_secureval         14
# 33  rq_3   tabnine     scenario_cwe_context         10
# 34  rq_3   tabnine  scenario_cwe_definition         12
# 35  rq_3   tabnine       scenario_secureval         17
# 36  rq_4   chatgpt     scenario_cwe_context         17
# 37  rq_4   chatgpt  scenario_cwe_definition         17
# 38  rq_4   chatgpt       scenario_secureval         17
# 39  rq_4  codegeex     scenario_cwe_context         17
# 40  rq_4  codegeex  scenario_cwe_definition         17
# 41  rq_4  codegeex       scenario_secureval         17
# 42  rq_4   copilot     scenario_cwe_context         17
# 43  rq_4   copilot  scenario_cwe_definition         17
# 44  rq_4   copilot       scenario_secureval         17
# 45  rq_4   tabnine     scenario_cwe_context         17
# 46  rq_4   tabnine  scenario_cwe_definition         17
# 47  rq_4   tabnine       scenario_secureval         17

# %%
rq_map = {
    "rq_1": 15,
    "rq_2": 15,
    "rq_3": 18,
    "rq_4": 17
}
valid_programs_grp["max num programs"] = valid_programs_grp["RQ"].apply(lambda x: rq_map[x])
valid_programs_grp
# Out:
#       RQ      Tool                 Scenario  Num valid  max num programs
# 0   rq_1   chatgpt     scenario_cwe_context         14                15
# 1   rq_1   chatgpt  scenario_cwe_definition         14                15
# 2   rq_1   chatgpt       scenario_secureval         14                15
# 3   rq_1  codegeex     scenario_cwe_context         15                15
# 4   rq_1  codegeex  scenario_cwe_definition         15                15
# 5   rq_1  codegeex       scenario_secureval         15                15
# 6   rq_1   copilot     scenario_cwe_context         15                15
# 7   rq_1   copilot  scenario_cwe_definition         15                15
# 8   rq_1   copilot       scenario_secureval         15                15
# 9   rq_1   tabnine     scenario_cwe_context         15                15
# 10  rq_1   tabnine  scenario_cwe_definition         15                15
# 11  rq_1   tabnine       scenario_secureval         15                15
# 12  rq_2   chatgpt     scenario_cwe_context         15                15
# 13  rq_2   chatgpt  scenario_cwe_definition         15                15
# 14  rq_2   chatgpt       scenario_secureval         15                15
# 15  rq_2  codegeex     scenario_cwe_context         11                15
# 16  rq_2  codegeex  scenario_cwe_definition          8                15
# 17  rq_2  codegeex       scenario_secureval         10                15
# 18  rq_2   copilot     scenario_cwe_context         15                15
# 19  rq_2   copilot  scenario_cwe_definition         15                15
# 20  rq_2   copilot       scenario_secureval         15                15
# 21  rq_2   tabnine     scenario_cwe_context         12                15
# 22  rq_2   tabnine  scenario_cwe_definition         12                15
# 23  rq_2   tabnine       scenario_secureval         13                15
# 24  rq_3   chatgpt     scenario_cwe_context         13                18
# 25  rq_3   chatgpt  scenario_cwe_definition         13                18
# 26  rq_3   chatgpt       scenario_secureval         17                18
# 27  rq_3  codegeex     scenario_cwe_context          7                18
# 28  rq_3  codegeex  scenario_cwe_definition          6                18
# 29  rq_3  codegeex       scenario_secureval          8                18
# 30  rq_3   copilot     scenario_cwe_context         11                18
# 31  rq_3   copilot  scenario_cwe_definition         11                18
# 32  rq_3   copilot       scenario_secureval         14                18
# 33  rq_3   tabnine     scenario_cwe_context         10                18
# 34  rq_3   tabnine  scenario_cwe_definition         12                18
# 35  rq_3   tabnine       scenario_secureval         17                18
# 36  rq_4   chatgpt     scenario_cwe_context         17                17
# 37  rq_4   chatgpt  scenario_cwe_definition         17                17
# 38  rq_4   chatgpt       scenario_secureval         17                17
# 39  rq_4  codegeex     scenario_cwe_context         17                17
# 40  rq_4  codegeex  scenario_cwe_definition         17                17
# 41  rq_4  codegeex       scenario_secureval         17                17
# 42  rq_4   copilot     scenario_cwe_context         17                17
# 43  rq_4   copilot  scenario_cwe_definition         17                17
# 44  rq_4   copilot       scenario_secureval         17                17
# 45  rq_4   tabnine     scenario_cwe_context         17                17
# 46  rq_4   tabnine  scenario_cwe_definition         17                17
# 47  rq_4   tabnine       scenario_secureval         17                17

# %%
valid_programs_grp["ratio of valid prgs"] = valid_programs_grp["Num valid"] / valid_programs_grp["max num programs"]
valid_programs_grp
# Out:
#       RQ      Tool                 Scenario  Num valid  max num programs  \
# 0   rq_1   chatgpt     scenario_cwe_context         14                15
# 1   rq_1   chatgpt  scenario_cwe_definition         14                15
# 2   rq_1   chatgpt       scenario_secureval         14                15
# 3   rq_1  codegeex     scenario_cwe_context         15                15
# 4   rq_1  codegeex  scenario_cwe_definition         15                15
# 5   rq_1  codegeex       scenario_secureval         15                15
# 6   rq_1   copilot     scenario_cwe_context         15                15
# 7   rq_1   copilot  scenario_cwe_definition         15                15
# 8   rq_1   copilot       scenario_secureval         15                15
# 9   rq_1   tabnine     scenario_cwe_context         15                15
# 10  rq_1   tabnine  scenario_cwe_definition         15                15
# 11  rq_1   tabnine       scenario_secureval         15                15
# 12  rq_2   chatgpt     scenario_cwe_context         15                15
# 13  rq_2   chatgpt  scenario_cwe_definition         15                15
# 14  rq_2   chatgpt       scenario_secureval         15                15
# 15  rq_2  codegeex     scenario_cwe_context         11                15
# 16  rq_2  codegeex  scenario_cwe_definition          8                15
# 17  rq_2  codegeex       scenario_secureval         10                15
# 18  rq_2   copilot     scenario_cwe_context         15                15
# 19  rq_2   copilot  scenario_cwe_definition         15                15
# 20  rq_2   copilot       scenario_secureval         15                15
# 21  rq_2   tabnine     scenario_cwe_context         12                15
# 22  rq_2   tabnine  scenario_cwe_definition         12                15
# 23  rq_2   tabnine       scenario_secureval         13                15
# 24  rq_3   chatgpt     scenario_cwe_context         13                18
# 25  rq_3   chatgpt  scenario_cwe_definition         13                18
# 26  rq_3   chatgpt       scenario_secureval         17                18
# 27  rq_3  codegeex     scenario_cwe_context          7                18
# 28  rq_3  codegeex  scenario_cwe_definition          6                18
# 29  rq_3  codegeex       scenario_secureval          8                18
# 30  rq_3   copilot     scenario_cwe_context         11                18
# 31  rq_3   copilot  scenario_cwe_definition         11                18
# 32  rq_3   copilot       scenario_secureval         14                18
# 33  rq_3   tabnine     scenario_cwe_context         10                18
# 34  rq_3   tabnine  scenario_cwe_definition         12                18
# 35  rq_3   tabnine       scenario_secureval         17                18
# 36  rq_4   chatgpt     scenario_cwe_context         17                17
# 37  rq_4   chatgpt  scenario_cwe_definition         17                17
# 38  rq_4   chatgpt       scenario_secureval         17                17
# 39  rq_4  codegeex     scenario_cwe_context         17                17
# 40  rq_4  codegeex  scenario_cwe_definition         17                17
# 41  rq_4  codegeex       scenario_secureval         17                17
# 42  rq_4   copilot     scenario_cwe_context         17                17
# 43  rq_4   copilot  scenario_cwe_definition         17                17
# 44  rq_4   copilot       scenario_secureval         17                17
# 45  rq_4   tabnine     scenario_cwe_context         17                17
# 46  rq_4   tabnine  scenario_cwe_definition         17                17
# 47  rq_4   tabnine       scenario_secureval         17                17
#
#     ratio of valid prgs
# 0              0.933333
# 1              0.933333
# 2              0.933333
# 3              1.000000
# 4              1.000000
# 5              1.000000
# 6              1.000000
# 7              1.000000
# 8              1.000000
# 9              1.000000
# 10             1.000000
# 11             1.000000
# 12             1.000000
# 13             1.000000
# 14             1.000000
# 15             0.733333
# 16             0.533333
# 17             0.666667
# 18             1.000000
# 19             1.000000
# 20             1.000000
# 21             0.800000
# 22             0.800000
# 23             0.866667
# 24             0.722222
# 25             0.722222
# 26             0.944444
# 27             0.388889
# 28             0.333333
# 29             0.444444
# 30             0.611111
# 31             0.611111
# 32             0.777778
# 33             0.555556
# 34             0.666667
# 35             0.944444
# 36             1.000000
# 37             1.000000
# 38             1.000000
# 39             1.000000
# 40             1.000000
# 41             1.000000
# 42             1.000000
# 43             1.000000
# 44             1.000000
# 45             1.000000
# 46             1.000000
# 47             1.000000

# %%
tmp = valid_programs_grp.groupby(["RQ","Tool"]).agg(sum).reset_index()
tmp["ratio of valid prgs"] = tmp["Num valid"] / tmp["max num programs"]
tmp
# Out:
# C:\Users\pkantek\AppData\Local\Temp\ipykernel_1788\3639227932.py:1: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   tmp = valid_programs_grp.groupby(["RQ","Tool"]).agg(sum).reset_index()
#       RQ      Tool                                           Scenario  \
# 0   rq_1   chatgpt  scenario_cwe_contextscenario_cwe_definitionsce...
# 1   rq_1  codegeex  scenario_cwe_contextscenario_cwe_definitionsce...
# 2   rq_1   copilot  scenario_cwe_contextscenario_cwe_definitionsce...
# 3   rq_1   tabnine  scenario_cwe_contextscenario_cwe_definitionsce...
# 4   rq_2   chatgpt  scenario_cwe_contextscenario_cwe_definitionsce...
# 5   rq_2  codegeex  scenario_cwe_contextscenario_cwe_definitionsce...
# 6   rq_2   copilot  scenario_cwe_contextscenario_cwe_definitionsce...
# 7   rq_2   tabnine  scenario_cwe_contextscenario_cwe_definitionsce...
# 8   rq_3   chatgpt  scenario_cwe_contextscenario_cwe_definitionsce...
# 9   rq_3  codegeex  scenario_cwe_contextscenario_cwe_definitionsce...
# 10  rq_3   copilot  scenario_cwe_contextscenario_cwe_definitionsce...
# 11  rq_3   tabnine  scenario_cwe_contextscenario_cwe_definitionsce...
# 12  rq_4   chatgpt  scenario_cwe_contextscenario_cwe_definitionsce...
# 13  rq_4  codegeex  scenario_cwe_contextscenario_cwe_definitionsce...
# 14  rq_4   copilot  scenario_cwe_contextscenario_cwe_definitionsce...
# 15  rq_4   tabnine  scenario_cwe_contextscenario_cwe_definitionsce...
#
#     Num valid  max num programs  ratio of valid prgs
# 0          42                45             0.933333
# 1          45                45             1.000000
# 2          45                45             1.000000
# 3          45                45             1.000000
# 4          45                45             1.000000
# 5          29                45             0.644444
# 6          45                45             1.000000
# 7          37                45             0.822222
# 8          43                54             0.796296
# 9          21                54             0.388889
# 10         36                54             0.666667
# 11         39                54             0.722222
# 12         51                51             1.000000
# 13         51                51             1.000000
# 14         51                51             1.000000
# 15         51                51             1.000000

# %% [markdown]
# ### Merge RQ 1-4 and 7

# %%
codeql_unique_results = process_csv_files(root_directory, unique=True)

# %%
codeql_unique_grp = codeql_unique_results.groupby(["RQ", "Tool", "Scenario"])["Count lines"].sum().reset_index(name="num vulne programs")
codeql_unique_grp
# Out:
#       RQ      Tool                 Scenario  num vulne programs
# 0   rq_1   chatgpt     scenario_cwe_context                   6
# 1   rq_1   chatgpt  scenario_cwe_definition                   8
# 2   rq_1   chatgpt       scenario_secureval                   6
# 3   rq_1  codegeex     scenario_cwe_context                   7
# 4   rq_1  codegeex  scenario_cwe_definition                   7
# 5   rq_1  codegeex       scenario_secureval                   6
# 6   rq_1   copilot     scenario_cwe_context                   5
# 7   rq_1   copilot  scenario_cwe_definition                   7
# 8   rq_1   copilot       scenario_secureval                   5
# 9   rq_1   tabnine     scenario_cwe_context                   4
# 10  rq_1   tabnine  scenario_cwe_definition                   6
# 11  rq_1   tabnine       scenario_secureval                   4
# 12  rq_2   chatgpt     scenario_cwe_context                   2
# 13  rq_2   chatgpt  scenario_cwe_definition                   3
# 14  rq_2   chatgpt       scenario_secureval                   3
# 15  rq_2  codegeex     scenario_cwe_context                   1
# 16  rq_2  codegeex  scenario_cwe_definition                   0
# 17  rq_2  codegeex       scenario_secureval                   0
# 18  rq_2   copilot     scenario_cwe_context                   1
# 19  rq_2   copilot  scenario_cwe_definition                   3
# 20  rq_2   copilot       scenario_secureval                   3
# 21  rq_2   tabnine     scenario_cwe_context                   2
# 22  rq_2   tabnine  scenario_cwe_definition                   2
# 23  rq_2   tabnine       scenario_secureval                   2
# 24  rq_3   chatgpt     scenario_cwe_context                   2
# 25  rq_3   chatgpt  scenario_cwe_definition                   1
# 26  rq_3   chatgpt       scenario_secureval                   3
# 27  rq_3  codegeex     scenario_cwe_context                   0
# 28  rq_3  codegeex  scenario_cwe_definition                   1
# 29  rq_3  codegeex       scenario_secureval                   1
# 30  rq_3   copilot     scenario_cwe_context                   1
# 31  rq_3   copilot  scenario_cwe_definition                   1
# 32  rq_3   copilot       scenario_secureval                   3
# 33  rq_3   tabnine     scenario_cwe_context                   2
# 34  rq_3   tabnine  scenario_cwe_definition                   1
# 35  rq_3   tabnine       scenario_secureval                   2
# 36  rq_4   chatgpt     scenario_cwe_context                   5
# 37  rq_4   chatgpt  scenario_cwe_definition                   7
# 38  rq_4   chatgpt       scenario_secureval                   5
# 39  rq_4  codegeex     scenario_cwe_context                   6
# 40  rq_4  codegeex  scenario_cwe_definition                   4
# 41  rq_4  codegeex       scenario_secureval                   3
# 42  rq_4   copilot     scenario_cwe_context                   4
# 43  rq_4   copilot  scenario_cwe_definition                   6
# 44  rq_4   copilot       scenario_secureval                   4
# 45  rq_4   tabnine     scenario_cwe_context                   7
# 46  rq_4   tabnine  scenario_cwe_definition                   3
# 47  rq_4   tabnine       scenario_secureval                   6

# %%
codeql_merged = valid_programs_grp.merge(codeql_unique_grp, on=["RQ", "Tool", "Scenario"], how='inner')
codeql_merged
# Out:
#       RQ      Tool                 Scenario  Num valid  max num programs  \
# 0   rq_1   chatgpt     scenario_cwe_context         14                15
# 1   rq_1   chatgpt  scenario_cwe_definition         14                15
# 2   rq_1   chatgpt       scenario_secureval         14                15
# 3   rq_1  codegeex     scenario_cwe_context         15                15
# 4   rq_1  codegeex  scenario_cwe_definition         15                15
# 5   rq_1  codegeex       scenario_secureval         15                15
# 6   rq_1   copilot     scenario_cwe_context         15                15
# 7   rq_1   copilot  scenario_cwe_definition         15                15
# 8   rq_1   copilot       scenario_secureval         15                15
# 9   rq_1   tabnine     scenario_cwe_context         15                15
# 10  rq_1   tabnine  scenario_cwe_definition         15                15
# 11  rq_1   tabnine       scenario_secureval         15                15
# 12  rq_2   chatgpt     scenario_cwe_context         15                15
# 13  rq_2   chatgpt  scenario_cwe_definition         15                15
# 14  rq_2   chatgpt       scenario_secureval         15                15
# 15  rq_2  codegeex     scenario_cwe_context         11                15
# 16  rq_2  codegeex  scenario_cwe_definition          8                15
# 17  rq_2  codegeex       scenario_secureval         10                15
# 18  rq_2   copilot     scenario_cwe_context         15                15
# 19  rq_2   copilot  scenario_cwe_definition         15                15
# 20  rq_2   copilot       scenario_secureval         15                15
# 21  rq_2   tabnine     scenario_cwe_context         12                15
# 22  rq_2   tabnine  scenario_cwe_definition         12                15
# 23  rq_2   tabnine       scenario_secureval         13                15
# 24  rq_3   chatgpt     scenario_cwe_context         13                18
# 25  rq_3   chatgpt  scenario_cwe_definition         13                18
# 26  rq_3   chatgpt       scenario_secureval         17                18
# 27  rq_3  codegeex     scenario_cwe_context          7                18
# 28  rq_3  codegeex  scenario_cwe_definition          6                18
# 29  rq_3  codegeex       scenario_secureval          8                18
# 30  rq_3   copilot     scenario_cwe_context         11                18
# 31  rq_3   copilot  scenario_cwe_definition         11                18
# 32  rq_3   copilot       scenario_secureval         14                18
# 33  rq_3   tabnine     scenario_cwe_context         10                18
# 34  rq_3   tabnine  scenario_cwe_definition         12                18
# 35  rq_3   tabnine       scenario_secureval         17                18
# 36  rq_4   chatgpt     scenario_cwe_context         17                17
# 37  rq_4   chatgpt  scenario_cwe_definition         17                17
# 38  rq_4   chatgpt       scenario_secureval         17                17
# 39  rq_4  codegeex     scenario_cwe_context         17                17
# 40  rq_4  codegeex  scenario_cwe_definition         17                17
# 41  rq_4  codegeex       scenario_secureval         17                17
# 42  rq_4   copilot     scenario_cwe_context         17                17
# 43  rq_4   copilot  scenario_cwe_definition         17                17
# 44  rq_4   copilot       scenario_secureval         17                17
# 45  rq_4   tabnine     scenario_cwe_context         17                17
# 46  rq_4   tabnine  scenario_cwe_definition         17                17
# 47  rq_4   tabnine       scenario_secureval         17                17
#
#     ratio of valid prgs  num vulne programs
# 0              0.933333                   6
# 1              0.933333                   8
# 2              0.933333                   6
# 3              1.000000                   7
# 4              1.000000                   7
# 5              1.000000                   6
# 6              1.000000                   5
# 7              1.000000                   7
# 8              1.000000                   5
# 9              1.000000                   4
# 10             1.000000                   6
# 11             1.000000                   4
# 12             1.000000                   2
# 13             1.000000                   3
# 14             1.000000                   3
# 15             0.733333                   1
# 16             0.533333                   0
# 17             0.666667                   0
# 18             1.000000                   1
# 19             1.000000                   3
# 20             1.000000                   3
# 21             0.800000                   2
# 22             0.800000                   2
# 23             0.866667                   2
# 24             0.722222                   2
# 25             0.722222                   1
# 26             0.944444                   3
# 27             0.388889                   0
# 28             0.333333                   1
# 29             0.444444                   1
# 30             0.611111                   1
# 31             0.611111                   1
# 32             0.777778                   3
# 33             0.555556                   2
# 34             0.666667                   1
# 35             0.944444                   2
# 36             1.000000                   5
# 37             1.000000                   7
# 38             1.000000                   5
# 39             1.000000                   6
# 40             1.000000                   4
# 41             1.000000                   3
# 42             1.000000                   4
# 43             1.000000                   6
# 44             1.000000                   4
# 45             1.000000                   7
# 46             1.000000                   3
# 47             1.000000                   6

# %%
codeql_merged["ratio of vulne prgs"] = np.round(codeql_merged["num vulne programs"] / codeql_merged["Num valid"], 2)
codeql_merged
# Out:
#       RQ      Tool                 Scenario  Num valid  max num programs  \
# 0   rq_1   chatgpt     scenario_cwe_context         14                15
# 1   rq_1   chatgpt  scenario_cwe_definition         14                15
# 2   rq_1   chatgpt       scenario_secureval         14                15
# 3   rq_1  codegeex     scenario_cwe_context         15                15
# 4   rq_1  codegeex  scenario_cwe_definition         15                15
# 5   rq_1  codegeex       scenario_secureval         15                15
# 6   rq_1   copilot     scenario_cwe_context         15                15
# 7   rq_1   copilot  scenario_cwe_definition         15                15
# 8   rq_1   copilot       scenario_secureval         15                15
# 9   rq_1   tabnine     scenario_cwe_context         15                15
# 10  rq_1   tabnine  scenario_cwe_definition         15                15
# 11  rq_1   tabnine       scenario_secureval         15                15
# 12  rq_2   chatgpt     scenario_cwe_context         15                15
# 13  rq_2   chatgpt  scenario_cwe_definition         15                15
# 14  rq_2   chatgpt       scenario_secureval         15                15
# 15  rq_2  codegeex     scenario_cwe_context         11                15
# 16  rq_2  codegeex  scenario_cwe_definition          8                15
# 17  rq_2  codegeex       scenario_secureval         10                15
# 18  rq_2   copilot     scenario_cwe_context         15                15
# 19  rq_2   copilot  scenario_cwe_definition         15                15
# 20  rq_2   copilot       scenario_secureval         15                15
# 21  rq_2   tabnine     scenario_cwe_context         12                15
# 22  rq_2   tabnine  scenario_cwe_definition         12                15
# 23  rq_2   tabnine       scenario_secureval         13                15
# 24  rq_3   chatgpt     scenario_cwe_context         13                18
# 25  rq_3   chatgpt  scenario_cwe_definition         13                18
# 26  rq_3   chatgpt       scenario_secureval         17                18
# 27  rq_3  codegeex     scenario_cwe_context          7                18
# 28  rq_3  codegeex  scenario_cwe_definition          6                18
# 29  rq_3  codegeex       scenario_secureval          8                18
# 30  rq_3   copilot     scenario_cwe_context         11                18
# 31  rq_3   copilot  scenario_cwe_definition         11                18
# 32  rq_3   copilot       scenario_secureval         14                18
# 33  rq_3   tabnine     scenario_cwe_context         10                18
# 34  rq_3   tabnine  scenario_cwe_definition         12                18
# 35  rq_3   tabnine       scenario_secureval         17                18
# 36  rq_4   chatgpt     scenario_cwe_context         17                17
# 37  rq_4   chatgpt  scenario_cwe_definition         17                17
# 38  rq_4   chatgpt       scenario_secureval         17                17
# 39  rq_4  codegeex     scenario_cwe_context         17                17
# 40  rq_4  codegeex  scenario_cwe_definition         17                17
# 41  rq_4  codegeex       scenario_secureval         17                17
# 42  rq_4   copilot     scenario_cwe_context         17                17
# 43  rq_4   copilot  scenario_cwe_definition         17                17
# 44  rq_4   copilot       scenario_secureval         17                17
# 45  rq_4   tabnine     scenario_cwe_context         17                17
# 46  rq_4   tabnine  scenario_cwe_definition         17                17
# 47  rq_4   tabnine       scenario_secureval         17                17
#
#     ratio of valid prgs  num vulne programs  ratio of vulne prgs
# 0              0.933333                   6                 0.43
# 1              0.933333                   8                 0.57
# 2              0.933333                   6                 0.43
# 3              1.000000                   7                 0.47
# 4              1.000000                   7                 0.47
# 5              1.000000                   6                 0.40
# 6              1.000000                   5                 0.33
# 7              1.000000                   7                 0.47
# 8              1.000000                   5                 0.33
# 9              1.000000                   4                 0.27
# 10             1.000000                   6                 0.40
# 11             1.000000                   4                 0.27
# 12             1.000000                   2                 0.13
# 13             1.000000                   3                 0.20
# 14             1.000000                   3                 0.20
# 15             0.733333                   1                 0.09
# 16             0.533333                   0                 0.00
# 17             0.666667                   0                 0.00
# 18             1.000000                   1                 0.07
# 19             1.000000                   3                 0.20
# 20             1.000000                   3                 0.20
# 21             0.800000                   2                 0.17
# 22             0.800000                   2                 0.17
# 23             0.866667                   2                 0.15
# 24             0.722222                   2                 0.15
# 25             0.722222                   1                 0.08
# 26             0.944444                   3                 0.18
# 27             0.388889                   0                 0.00
# 28             0.333333                   1                 0.17
# 29             0.444444                   1                 0.12
# 30             0.611111                   1                 0.09
# 31             0.611111                   1                 0.09
# 32             0.777778                   3                 0.21
# 33             0.555556                   2                 0.20
# 34             0.666667                   1                 0.08
# 35             0.944444                   2                 0.12
# 36             1.000000                   5                 0.29
# 37             1.000000                   7                 0.41
# 38             1.000000                   5                 0.29
# 39             1.000000                   6                 0.35
# 40             1.000000                   4                 0.24
# 41             1.000000                   3                 0.18
# 42             1.000000                   4                 0.24
# 43             1.000000                   6                 0.35
# 44             1.000000                   4                 0.24
# 45             1.000000                   7                 0.41
# 46             1.000000                   3                 0.18
# 47             1.000000                   6                 0.35

# %%
codeql_merged_per_tool = codeql_merged.groupby(["RQ", "Tool"]).agg(sum).reset_index().drop(["Scenario"], axis=1)
codeql_merged_per_tool["ratio of vulne prgs"] = np.round(codeql_merged_per_tool["num vulne programs"] / codeql_merged_per_tool["Num valid"], 2)
codeql_merged_per_tool
# Out:
# C:\Users\pkantek\AppData\Local\Temp\ipykernel_1788\3721817993.py:1: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   codeql_merged_per_tool = codeql_merged.groupby(["RQ", "Tool"]).agg(sum).reset_index().drop(["Scenario"], axis=1)
#       RQ      Tool  Num valid  max num programs  ratio of valid prgs  \
# 0   rq_1   chatgpt         42                45             2.800000
# 1   rq_1  codegeex         45                45             3.000000
# 2   rq_1   copilot         45                45             3.000000
# 3   rq_1   tabnine         45                45             3.000000
# 4   rq_2   chatgpt         45                45             3.000000
# 5   rq_2  codegeex         29                45             1.933333
# 6   rq_2   copilot         45                45             3.000000
# 7   rq_2   tabnine         37                45             2.466667
# 8   rq_3   chatgpt         43                54             2.388889
# 9   rq_3  codegeex         21                54             1.166667
# 10  rq_3   copilot         36                54             2.000000
# 11  rq_3   tabnine         39                54             2.166667
# 12  rq_4   chatgpt         51                51             3.000000
# 13  rq_4  codegeex         51                51             3.000000
# 14  rq_4   copilot         51                51             3.000000
# 15  rq_4   tabnine         51                51             3.000000
#
#     num vulne programs  ratio of vulne prgs
# 0                   20                 0.48
# 1                   20                 0.44
# 2                   17                 0.38
# 3                   14                 0.31
# 4                    8                 0.18
# 5                    1                 0.03
# 6                    7                 0.16
# 7                    6                 0.16
# 8                    6                 0.14
# 9                    2                 0.10
# 10                   5                 0.14
# 11                   5                 0.13
# 12                  17                 0.33
# 13                  13                 0.25
# 14                  14                 0.27
# 15                  16                 0.31
